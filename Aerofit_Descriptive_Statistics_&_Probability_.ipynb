# %% [markdown]
# <a href="https://colab.research.google.com/github/asha-murthy/DataScientist/blob/main/Aerofit_Descriptive_Statistics_%26_Probability_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries , Loading the data and Basic Observations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('aerofit_treadmill.csv')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180
#
# [180 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# unique         NaN            NaN         NaN
# top            NaN            NaN         NaN
# freq           NaN            NaN         NaN
# mean      3.311111   53719.577778  103.194444
# std       0.958869   16506.684226   51.863605
# min       1.000000   29562.000000   21.000000
# 25%       3.000000   44058.750000   66.000000
# 50%       3.000000   50596.500000   94.000000
# 75%       4.000000   58668.000000  114.750000
# max       5.000000  104581.000000  360.000000

# %% [markdown]
# Insights:
#
# *  Data Shape : 180 rows and 9 columns
# *  Data Type of each Category looks good
# *   3 Unique Products : KP281 is the most frequent product
# *   Males are more in numbers i.e 104 and rest are Females
# *   Married people (107) considerably buying treadmills
# *  Average Age is 29 with 75% of audience have an age less than or equal to 33. Minimum age is 18 and maximum is 50
# *   Average years of Education is 16 which is equivalent to 75% of the audience
# *   Standard Deviation is quite high in case of 'Income' and 'Miles' which must be due to outliers

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset.

# %% [markdown]
# # **Non-Graphical Analysis**

# %%
df['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %% [markdown]
# The Aerofit product line consists of three models: KP281, KP481, and KP781.

# %% [markdown]
# Marginal Probability

# %%
df.Product.value_counts()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
df.Product.value_counts(normalize = True)
# Out:
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: proportion, dtype: float64

# %% [markdown]
# The KP281 is the most popular product in the Aerofit line, accounting for 44.44% of total sales. The KP481 and KP781 models constitute 33.33% and 22.22% of total sales, respectively.

# %%
df.Age.value_counts()
# Out:
# Age
# 25    25
# 23    18
# 24    12
# 26    12
# 28     9
# 33     8
# 35     8
# 22     7
# 30     7
# 27     7
# 38     7
# 21     7
# 31     6
# 34     6
# 29     6
# 20     5
# 40     5
# 19     4
# 32     4
# 37     2
# 45     2
# 48     2
# 47     2
# 18     1
# 41     1
# 39     1
# 36     1
# 43     1
# 46     1
# 44     1
# 50     1
# 42     1
# Name: count, dtype: int64

# %%
df.Age.value_counts(normalize = True)
# Out:
# Age
# 25    0.138889
# 23    0.100000
# 24    0.066667
# 26    0.066667
# 28    0.050000
# 33    0.044444
# 35    0.044444
# 22    0.038889
# 30    0.038889
# 27    0.038889
# 38    0.038889
# 21    0.038889
# 31    0.033333
# 34    0.033333
# 29    0.033333
# 20    0.027778
# 40    0.027778
# 19    0.022222
# 32    0.022222
# 37    0.011111
# 45    0.011111
# 48    0.011111
# 47    0.011111
# 18    0.005556
# 41    0.005556
# 39    0.005556
# 36    0.005556
# 43    0.005556
# 46    0.005556
# 44    0.005556
# 50    0.005556
# 42    0.005556
# Name: proportion, dtype: float64

# %% [markdown]
# Customers aged 25 represent the largest segment of product buyers, accounting for 13.88% of total purchases.

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
df.Gender.value_counts(normalize = True)
# Out:
# Gender
# Male      0.577778
# Female    0.422222
# Name: proportion, dtype: float64

# %% [markdown]
# Male customers constitute the largest segment of product buyers, accounting for 57.77% of total purchases, while female customers constitute the remaining 42.22%.

# %%
df.Education.value_counts()
# Out:
# Education
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: count, dtype: int64

# %%
df.Education.value_counts(normalize = True)
# Out:
# Education
# 16    0.472222
# 14    0.305556
# 18    0.127778
# 15    0.027778
# 13    0.027778
# 12    0.016667
# 21    0.016667
# 20    0.005556
# Name: proportion, dtype: float64

# %% [markdown]
# Customers with 16 years of education constitute the largest segment of product buyers, representing 47.22% of total purchases.

# %%
df.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
df.MaritalStatus.value_counts(normalize = True)
# Out:
# MaritalStatus
# Partnered    0.594444
# Single       0.405556
# Name: proportion, dtype: float64

# %% [markdown]
# Partnered customers represent the largest segment of product buyers, accounting for 59% of total purchases, while single customers constitute the remaining 40.55%

# %%
df.Usage.value_counts()
# Out:
# Usage
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: count, dtype: int64

# %%
df.Usage.value_counts(normalize = True)
# Out:
# Usage
# 3    0.383333
# 4    0.288889
# 2    0.183333
# 5    0.094444
# 6    0.038889
# 7    0.011111
# Name: proportion, dtype: float64

# %% [markdown]
# Customers mostly use the treadmill 3 times per week, with 38.33%.

# %%
df.Fitness.value_counts()
# Out:
# Fitness
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: count, dtype: int64

# %%
df.Fitness.value_counts(normalize = True)
# Out:
# Fitness
# 3    0.538889
# 5    0.172222
# 2    0.144444
# 4    0.133333
# 1    0.011111
# Name: proportion, dtype: float64

# %% [markdown]
# Customers whose fitness level is 3 represent the largest segment of product buyers, accounting for 53.88% of total purchases.

# %%
df.Income.value_counts()
# Out:
# Income
# 45480     14
# 52302      9
# 53439      8
# 54576      8
# 46617      8
#           ..
# 85906      1
# 99601      1
# 103336     1
# 95866      1
# 95508      1
# Name: count, Length: 62, dtype: int64

# %%
df.Income.value_counts(normalize = True)
# Out:
# Income
# 45480     0.077778
# 52302     0.050000
# 53439     0.044444
# 54576     0.044444
# 46617     0.044444
#             ...
# 85906     0.005556
# 99601     0.005556
# 103336    0.005556
# 95866     0.005556
# 95508     0.005556
# Name: proportion, Length: 62, dtype: float64

# %% [markdown]
# Customers with an annual income of $45,480 represent the largest segment within the customer base, based on income distribution.

# %% [markdown]
# Conditional Probability

# %%
df_new=df
bins=[10,20,30,40,50,100]
labels=["10-20","20-30","30-40","40-50","50-100"]
df_new["Age_group"]=pd.cut(df_new["Age"],bins=bins,labels=labels)
df_new

bins1=[0,35000,60000,200000]
label1=["Lower_Income","Mid_Income","High_Income"]
df_new["Income_bins"]=pd.cut(df_new["Income"],bins=bins1,labels=label1)
df_new
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles Age_group   Income_bins
# 0      112     10-20  Lower_Income
# 1       75     10-20  Lower_Income
# 2       66     10-20  Lower_Income
# 3       85     10-20  Lower_Income
# 4       47     10-20    Mid_Income
# ..     ...       ...           ...
# 175    200     30-40   High_Income
# 176    200     40-50   High_Income
# 177    160     40-50   High_Income
# 178    120     40-50   High_Income
# 179    180     40-50   High_Income
#
# [180 rows x 11 columns]

# %%
pd.crosstab(df['Gender'],df['Product'],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %%
pd.crosstab(df['Gender'],df['Product'],normalize=True)
# Out:
# Product     KP281     KP481     KP781
# Gender
# Female   0.222222  0.161111  0.038889
# Male     0.222222  0.172222  0.183333

# %%
pd.crosstab(df['MaritalStatus'], df['Product'])
# Out:
# Product        KP281  KP481  KP781
# MaritalStatus
# Partnered         48     36     23
# Single            32     24     17

# %%
pd.crosstab(df['MaritalStatus'], df['Product'],normalize=True)
# Out:
# Product           KP281     KP481     KP781
# MaritalStatus
# Partnered      0.266667  0.200000  0.127778
# Single         0.177778  0.133333  0.094444

# %%
pd.crosstab(df_new['Age_group'],df['Product'],margins=True)
# Out:
# Product    KP281  KP481  KP781  All
# Age_group
# 10-20          6      4      0   10
# 20-30         49     31     30  110
# 30-40         19     23      6   48
# 40-50          6      2      4   12
# All           80     60     40  180

# %%
pd.crosstab(df_new['Age_group'],df['Product'],normalize=True)
# Out:
# Product       KP281     KP481     KP781
# Age_group
# 10-20      0.033333  0.022222  0.000000
# 20-30      0.272222  0.172222  0.166667
# 30-40      0.105556  0.127778  0.033333
# 40-50      0.033333  0.011111  0.022222

# %%
pd.crosstab(df['Education'],df['Product'],margins=True)
# Out:
# Product    KP281  KP481  KP781  All
# Education
# 12             2      1      0    3
# 13             3      2      0    5
# 14            30     23      2   55
# 15             4      1      0    5
# 16            39     31     15   85
# 18             2      2     19   23
# 20             0      0      1    1
# 21             0      0      3    3
# All           80     60     40  180

# %%
pd.crosstab(df['Education'],df['Product'],normalize=True)
# Out:
# Product       KP281     KP481     KP781
# Education
# 12         0.011111  0.005556  0.000000
# 13         0.016667  0.011111  0.000000
# 14         0.166667  0.127778  0.011111
# 15         0.022222  0.005556  0.000000
# 16         0.216667  0.172222  0.083333
# 18         0.011111  0.011111  0.105556
# 20         0.000000  0.000000  0.005556
# 21         0.000000  0.000000  0.016667

# %%
pd.crosstab(df['Usage'],df['Product'],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Usage
# 2           19     14      0   33
# 3           37     31      1   69
# 4           22     12     18   52
# 5            2      3     12   17
# 6            0      0      7    7
# 7            0      0      2    2
# All         80     60     40  180

# %%
pd.crosstab(df['Usage'],df['Product'],normalize=True)
# Out:
# Product     KP281     KP481     KP781
# Usage
# 2        0.105556  0.077778  0.000000
# 3        0.205556  0.172222  0.005556
# 4        0.122222  0.066667  0.100000
# 5        0.011111  0.016667  0.066667
# 6        0.000000  0.000000  0.038889
# 7        0.000000  0.000000  0.011111

# %%
pd.crosstab(df['Fitness'],df['Product'],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Fitness
# 1            1      1      0    2
# 2           14     12      0   26
# 3           54     39      4   97
# 4            9      8      7   24
# 5            2      0     29   31
# All         80     60     40  180

# %%
pd.crosstab(df['Fitness'],df['Product'],normalize=True)
# Out:
# Product     KP281     KP481     KP781
# Fitness
# 1        0.005556  0.005556  0.000000
# 2        0.077778  0.066667  0.000000
# 3        0.300000  0.216667  0.022222
# 4        0.050000  0.044444  0.038889
# 5        0.011111  0.000000  0.161111

# %%
pd.crosstab(df_new['Income_bins'],df['Product'],margins=True)
# Out:
# Product       KP281  KP481  KP781  All
# Income_bins
# Lower_Income      8      6      0   14
# Mid_Income       66     47     11  124
# High_Income       6      7     29   42
# All              80     60     40  180

# %%
pd.crosstab(df_new['Income_bins'],df['Product'],normalize=True)
# Out:
# Product          KP281     KP481     KP781
# Income_bins
# Lower_Income  0.044444  0.033333  0.000000
# Mid_Income    0.366667  0.261111  0.061111
# High_Income   0.033333  0.038889  0.161111

# %% [markdown]
# # **Outliers Detection:**

# %%
fig, axis = plt.subplots(3, 2, figsize=(10, 10))
#fig.subplots_adjust(top=1.0)
sns.boxplot(data=df, x="Age", orient='h', ax=axis[0,0],color='orange')
sns.boxplot(data=df, x="Education", orient='h', ax=axis[0,1],color='orange')
sns.boxplot(data=df, x="Usage", orient='h', ax=axis[1,0],color='orange')
sns.boxplot(data=df, x="Fitness", orient='h', ax=axis[1,1],color='orange')
sns.boxplot(data=df, x="Income", orient='h', ax=axis[2,0],color='orange')
sns.boxplot(data=df, x="Miles", orient='h', ax=axis[2,1],color='orange')
plt.show()

# %% [markdown]
# Income and Miles Categories have got more
# outliers.
# Age / Education / Usage and fitness have got negligible outliers.
# Since there are outliers, we will consider median of the attributes to derive correct inferences and reduce the effect of outliers.

# %% [markdown]
# # **Visual Analysis : Univariate and Bivariate**

# %% [markdown]
# Contribution of Each Categorical & Continuous data

# %%
fig,axis = plt.subplots(nrows = 2, ncols = 3, figsize = (12,5))
fig.subplots_adjust(top=1.2)
sns.histplot(df['Age'], ax=axis[0,0],kde = True,color='orange')
sns.histplot(df['Education'], ax=axis[0,1],kde = True,color='orange')
sns.histplot(df['Usage'], ax=axis[0,2],kde = True,color='orange')
sns.histplot(df['Fitness'], ax=axis[1,0],kde = True,color='orange')
sns.histplot(df['Income'], ax=axis[1,1],kde = True,color='orange')
sns.histplot(df['Miles'], ax=axis[1,2],kde = True,color='orange')
plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(12,5))
ax[0].pie(df['Product'].value_counts(),labels=df['Product'].value_counts().index,startangle=90,autopct='%1.1f%%')
ax[0].set_title('Product Distribution')
ax[1].pie(df['Gender'].value_counts(),labels=df['Gender'].value_counts().index,startangle=90,autopct='%1.1f%%')
ax[1].set_title('Gender Distribution')
ax[2].pie(df['MaritalStatus'].value_counts(),labels=df['MaritalStatus'].value_counts().index,startangle=90,autopct='%1.1f%%')
ax[2].set_title('Marital Status Distribution')
plt.show()

# %% [markdown]
# Gender Distribution on Purchase of Each Category of Treadmill

# %%
sns.countplot(data=df,x='Product',hue='Gender',palette='Set1')
plt.show()

# %% [markdown]
# *   Ratio of Males and Females buying an entry level Treadmill KP281 is same
# *   Males are slightly higher than Females in buying a mid-level product KP481
# *  Males mostly buy a high end Treadmill KP781 than Females.

# %% [markdown]
# Understanding Effect of Marital Status on Purchase of Each Category of Treadmill

# %%
sns.countplot(data=df,x='Product',hue='MaritalStatus',palette='Set2')
plt.show()

# %% [markdown]
# * Married population clearly dominates Singles while buying Treadmills of any Category
# *  The difference between buying capacity of Married w.r.t singles is maximum in case of Entry level Treadmill i.e KP281 followed by KP481 and then KP781
#
#
# *   Married and Singles both mostly buy entry level Treadmill KP281 which is economical

# %% [markdown]
# Distribution of Each Attribute on all 3 Products

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,3,1)
sns.boxplot(data=df,x='Product',y='Age')
plt.title("Age")
plt.xlabel("")
plt.ylabel("")

plt.subplot(2,3,2)
sns.boxplot(data=df,x='Product',y='Education')
plt.title("Education")
plt.xlabel("")
plt.ylabel("")

plt.subplot(2,3,3)
sns.boxplot(data=df,x='Product',y='Usage')
plt.title("Usage")
plt.xlabel("")
plt.ylabel("")

plt.subplot(2,3,4)
sns.boxplot(data=df,x='Product',y='Fitness')
plt.title("Fitness")
plt.xlabel("")
plt.ylabel("")

plt.subplot(2,3,5)
sns.boxplot(data=df,x='Product',y='Income')
plt.title("Income")
plt.xlabel("")
plt.ylabel("")

plt.subplot(2,3,6)
sns.boxplot(data=df,x='Product',y='Miles')
plt.title("Miles")
plt.xlabel("")
plt.ylabel("")

plt.show()

# %% [markdown]
# INSIGHTS
#
# Age:
#
# Most of the customers lie in the age group of 25-30 for all three products
# The advanced level Treadmill KP781 have got significant exceptions from the customers in the age group of 35-50
# Education:
#
# Entry level and Mid level Treadmill show same Education level mostly from 14-16
# The higher Education level 16-18 are more likely to buy advanced level Treadmill KP781
# Usage:
#
# Customers using Treadmill 3-4 times in a week are buying Entry level Treadmill KP281
# Customers using Treadmill 3 times in a week are more likely to buy KP481
# Customers using Treadmill 4-5 times in a week are buying advanced level Treadmill KP781
# Fitness:
#
# Customers who are fitness freak with a fitness level of 4-5 are mostly buying advanced level Treadmill KP781
#
# Income:
#
# Customers with income group of 40-50k are buying entry level Treadmill
# Customers with income of around 50k are likly to buy mid-level Treadmill
# Customers with income group of 60-90k are buying advanced level Treadmill
# Miles:
#
# Customers who walk / run average of 90 miles per week are buying KP281 and KP481
# Customers who walk / run around 150 miles per week are more likely to buy advanced level Treadmill KP781

# %% [markdown]
# Gender Wise Distribution of Each Attribute on the sale of Products

# %%
Cols = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
fig, axs = plt.subplots(3,2, figsize=(12, 11))
#fig.subplots_adjust(top=1)
cnt = 0
for i in range(3):
  for j in range(2):
    sns.boxplot(data=df,x='Gender', y=Cols[cnt], hue='Product',ax=axs[i,j])
    cnt += 1

# %% [markdown]
# INSIGHTS
#
# AGE:
#
# Females around 30 yearsof age are more likely to buy mid level Treadmill
# Males around 27 years of age are buying advanced end Treadmill
# Education:
#
# Males with higher education level likely to buy KP781 and similar is the case with females.
# Buying pattern is same for both males and females in case of entry and mid level Treadmills
# Usage:
#
# Males and Females with higher usage of 4-5 times a week are buying advanced Treadmill KP781
#
# Fitness:
#
# Both Males and Females having higher fitness levels are likely to buy advanced end Treadmill KP781
#
# Income:
#
# Males and Females in higher income groups are buying KP781 and with lower income groups are buying entry and mid level Treadmills
#
# Miles:
#
# Both males and females having covering more miles in a week are buying advanced end Treadmills

# %% [markdown]
# #Correlation
#
# Understanding Connections among each Category which will help us in Customer Profiling

# %%
sns.pairplot(data=df)

# %%
df.select_dtypes(include=np.number).corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(df.select_dtypes(include=np.number).corr(),annot=True,fmt=".2f",cmap="crest")
# Out:
# <Axes: >

# %% [markdown]
# *  Less variance in income is observed in case of lower ages as compared to higher ages
#
# *   Customers with lower income run /walk lesser miles w.r.t higher income group
# *   Fitness is strongly related to miles covered by the customers
#
#
# *  Customer's education is strongly related to Income
#
#
# *  Usage per week is strongly related to miles covered by customer

# %% [markdown]
# # **Recommendations / Customer Profiling**

# %% [markdown]
# Target Group:
#
# Males:
# Young Male:
#
# Age around 25 years is buying more Entry level and mid level Treadmills. We can introduce more products in this price range targeting this group and motivating them to buy through some sale schemes. This Target group shall give voulme sales than margins. Later when this male purchasing power increases ,he can buy our high end model. It can make way for our advanced end products and customer will remain loyal to our brand.
#
# Mid Aged Male:
#
# They tend to buy advanced end Treadmill KP 781 which shows their purchasing power is increased and how seriously they are considering their fitness. This Target group can give more revenue than volume sales. So having a marketing plan around it would defintely help increase revenue
#
# Educated Male:
#
# Males with higher education level i.e 16-18 buy advanced end Treadmills than with the ones with education level 14-16 who buy mostly low level and mid level equipment. We can market our product and introduce schemes basis this information. For Ex. we can have corporate offers show casing our high end treadmills, considering the fact that it will be our customer base for advanced end models.
#
# Fitness Freak Male:
#
# Data clearly shows the males with higher usage and higher fitness levels are clearly buying advanced end model KP781 only. We can find this target group in gyms, fitness centers.. for sportspersons, atheletes. He is the guy who is serious for his fitness and spending time and money on it. We need to sit with marketing team to have a plan to target this group and generate revenue.
#
# Higher / Lower Income Male:
#
# There is a residential or corporate area and we know that this place mostly higher income or lower income males are found. Basis this information we can device a marketing plan to push our products accordingly so that we do not waste marketing budget for higher end product where there are lower income males.
#
# Females:
# Young / Mid-Aged Females:
# Mostly Females in the age bracket of 25-30 are buying KP481 followed by KP281 which clearly shows our target group and how can we have a plan to pitch this group. 38% of females combined are buying KP281 andf KP481 which shows the potential this group have and the marketing effort we need to put for them.
#
# High Educated Female:
# Female with higher education level is buying advanced end Treadmill and the one with lower education level low end and mid end product. We can have a marketing plan around it accordingly.
#
# Fitness Freak Females:
# Females with higher usage and high fitness level are clearly buying advanced end Treadmill KP781. We can identify localities or corporates which there this TG is found like gyms , fitness centers.. and plan marketing around it accordingly.
#
# High Income Females: This group may find similarity with above group since these are the females who are buying advanced Treadmill only ,which means they have the purchasing power and they are serious for their fitness. We can identify such localities and societies and plan marketing event around them.
# Married / Single:
# It is observed that Singles are mainly buying low end Treadmills KP281 and KP481 which are less costly. It can be due to the reasons that most of them are students or have just started working and their purchasing power is less. This group can easily be identified near colleges / hostels where marketing can be planned or events can be planned to motivate them for their fitness and buy our economical Treadmills. We can introduce more models around this segment which will definitely help generate revenue ,although not much margin but volumes will be high. and if our quality is good he /she will be our future customer for our high end models. Since many married people are buying our Treadmills mostly KP281. That infers that there is big scope of introducing more models around it since mane married and singles are buying low end Treadmills due to cost involved.

# %% [markdown]
# # **Recommendations Summary:**

# %% [markdown]
# *  KP281 is recommended for males or females, married and singles in the age group of 24-34,education level of 14-16, usage in males 3-4, income 40-50k and miles covered between 50-100
# *   KP481 is recommended for ones having age between 24-34,education level 14-16, female's usage 3-4 times in a week, income around 50k and miles covered around 100
#
#
# *   KP781 is recommended for ones with age between 24-34, education between 16-18 levels, usage 4-5 times in a week, fitness level between 4 and 5, income between 60k -90k and miles covered between 100-200
# *   Considering above Customer Profiling and socio-economic factors we can clearly plan a marketing strategy around each Target Group.
#
# *  Above analysis shows that there is big market for entry level products which account for almost 78% of the sales. It is a big opportunity to get customer on board and then with great experience we are creating base for our advanced Treadmills
# *  Basis above information we can target our customers through digital media. By having customer profiles from some agency and planning social media interactions ,youtube ..etc
#
# *   Basis on the demography shared above we can plan some fitness event in that localty or area and accordingly pitch our products.
# *   With information and actionables shared we can definitely capture market share and increase our revenue
